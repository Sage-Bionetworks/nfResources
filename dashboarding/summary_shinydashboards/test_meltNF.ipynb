# %%
import pandas
import numpy
import datetime
import synapseutils
import synapseclient
from synapseclient import Entity, Project, Column, Team, Wiki

# %%
def synapseLogin():
    """
    First tries to login to synapse by finding the local auth key cached on user's computing platform, if not found,
    prompts the user to provide their synapse user name and password, then caches the auth key on their computing
    platform.

    :return:
    """
    try:
        syn = synapseclient.login()
    except Exception as e:
        print('Please provide your synapse username/email and password (You will only be prompted once)')
        username = input("Username: ")
        password = getpass.getpass(("Password for " + username + ": ").encode('utf-8'))
        syn = synapseclient.login(email=username, password=password, rememberMe=True)

    return syn

# %%
synapseLogin()
# Out:
# Welcome, xengie.doan!

# %%
def getdf(syn, id):
    """

    :param syn:
    :param id:
    :return:
    """
    df = syn.tableQuery('select * from {id}'.format(id=id)).asDataFrame()
    return df

# %%
"""
Create a master matrix/table for consortium metrics.

:param args:
:param syn:
:return:
"""
# project and publication attributes
p_atr = ['projectName',
         'id',
         'fundingAgency',
         'citation',
         'doi',
         'tumorType',
         'diseaseFocus']

# project attributes
# ### use project view syn11391664 for createdOn modifiedOn but missing projects
# p_view_atr = [ 'id',
#             'name',
#             'fundingAgency',
#             'consortium',
#             'etag',
#             'modifiedOn',
#             'modifiedBy',
#             'concreteType',
#             'dataContact',
#             'diseaseFocus',
#             'grantEnd',
#             'grantStart',
#             'isActive',
#             'principalInvestigator',
#             'projectTeam',
#             'tumorType',
#             'createdOn']

### from table syn16787123
p_view_atr = ['projectName',
              'id',
              'projectFileviewId',
              'projectStatus',
              'dataStatus',
              'fundingAgency',
              'summary',
              'summarySource',
              'projectLeads',
              'institutions',
              'tumorType',
              'diseaseFocus']


# file view attributes
f_atr = ['id',
        'name',
        'projectId',
        'assay',
        'consortium',
        'dataSubtype',
        'dataType',
        'diagnosis',
        'tumorType',
        'fileFormat',
        'fundingAgency',
        'individualID',
        'nf1Genotype',
        'nf2Genotype',
        'species',
        'resourceType',
        'isCellLine',
        'isMultiSpecimen',
        'isMultiIndividual',
        'studyId',
        'studyName',
        'benefactorId',
        'specimenID',
        'sex'
        'age',
        'readPair',
        'createdOn',
        'modifiedOn']

# csbc project info integration 
csbc_atr = ["projectId",
            "name_project",
            "consortium",
            "institution",
            "grantNumber",
            "grantType",
            "teamMembersProfileId",
            "teamProfileId",
            "createdOn_project",
            "modifiedOn_project",
            "publication_count",
            "publication_geodata_produced",
            "fileId","name_file",
            "createdOn_file",
            "modifiedOn_file",
            "age",
            "analysisType",
            "assay",
            "cellLine",
            "cellSubType",
            "cellType",
            "compoundDose",
            "compoundName",
            "concreteType",
            "dataSubtype",
            "dataType",
            "diagnosis",
            "diseaseSubtype",
            "dnaAlignmentMethod",
            "experimentalCondition",
            "experimentalTimePoint",
            "fileFormat",
            "fundingAgency",
            "individualID",
            "individualIdSource",
            "inputDataType",
            "isCellLine",
            "isPrimaryCell",
            "isStranded",
            "libraryPrep",
            "modelSystem",
            "organ",
            "outputDataType",
            "peakCallingMethod",
            "platform",
            "readLength",
            "resourceType",
            "rnaAlignmentMethod",
            "runType",
            "scriptLanguageVersion",
            "sex","softwareAuthor",
            "softwareLanguage",
            "softwareRepository",
            "softwareRepositoryType",
            "softwareType",
            "species",
            "specimenID",
            "study",
            "tissue",
            "transcriptQuantificationMethod",
            "transplantationDonorSpecies",
            "transplantationDonorTissue",
            "transplantationRecipientTissue",
            "transplantationType",
            "tumorType"]

# %%
# merging all the things
# 0 publications view syn16857542
# 1 project table  syn16787123
# 2 all portal - files syn16858331
# 3 tools syn9898965
views = ['syn16857542', 'syn16787123', 'syn16858331', 'syn16859448']

dfs = [getdf(synapseclient.login(), synid) for synid in views]
[d.reset_index(inplace=True, drop=True) for d in dfs]
# Out:
# Welcome, xengie.doan!
#
# Welcome, xengie.doan!
#
# Welcome, xengie.doan!
#
# Welcome, xengie.doan!
# [None, None, None, None]

# %%
# Project attributes
# change columns to represent project attributes and unify key name to be projectId
dfs[0].rename(index=str, columns={"id": "projectId", "name" : "projectName"}, inplace=True)
dfs[1].rename(index=str, columns={"id": "projectId", "name": "projectName"}, inplace=True)

# %%
# take out non NTAP funded projects
dfs[0] = dfs[0][~dfs[0].fundingAgency.isin(['CTF', 'NIH-NCI'])]
dfs[1] = dfs[1][~dfs[1].fundingAgency.isin(['CTF', 'NIH-NCI'])]
dfs[2] = dfs[2][~dfs[2].fundingAgency.isin(['CTF', 'NIH-NCI', ''])]
dfs[3] = dfs[3][~dfs[3].fundingAgency.isin(['CTF', 'NIH-NCI', ''])]

# %%
# pandas.options.display.max_columns=50

# %%
# there are projects without publications
len(set(dfs[1].projectId.unique()) - set(dfs[0].projectId.unique()))
# Out:
# 32

# %%
# Associate publications information to projects
project_info_df = pandas.merge(dfs[1], dfs[0], on=['projectId','projectName', 'fundingAgency', 'diseaseFocus', 'tumorType'], how='left')

# %%
project_info_df
# Out:
#                                           projectName    projectId  \
# 0                3D Models of Cutaneous Neurofibromas  syn11374354
# 1    A Nerve Sheath Tumor Bank from Patients with NF1   syn4939902
# 2   A Robust Plexiform Neurofibroma Model for Prec...   syn8016635
# 3            Acceptance and Commitment Therapy in NF1   syn4939896
# 4    Can Targeted Therapy Prevent Neurofibroma Growth   syn4939872
# 5                  Child NF1 Quality of Life Measures   syn4939878
# 6                  Child NF1 Quality of Life Measures   syn4939878
# 7                Combination Index Validation Studies   syn4939876
# 8   Cutaneous Neurofibroma - Models, Biology, and ...  syn11374333
# 9       Deconstruction and Reconstruction of NF1 cNFs  syn11374357
# 10  Development of Needs-based Quality of Life Pat...   syn4939880
# 11    Development of Patient Reported Outcomes System   syn4939888
# 12    Development of Patient Reported Outcomes System   syn4939888
# 13    Development of Patient Reported Outcomes System   syn4939888
# 14    Development of Patient Reported Outcomes System   syn4939888
# 15                   Drug Screening of pNF Cell Lines   syn4939906
# 16  Expression of cNFs Due to Schwann Cell-Fibrobl...  syn11374353
# 17                   Genetic Studies of Neurofibromas  syn11374339
# 18  Identifying preclinical predictors of clinical...  syn12051335
# 19            Imaging Biomarkers of Neurofibromatosis   syn4939894
# 20  Leveraging iPSCs to Determine Impact of NF1 Mu...  syn11374345
# 21  Microenvironmental Targets of Cutaneous Neurof...  syn11374341
# 22  Modeling signaling networks of NF1-deficient S...   syn8016599
# 23             NF Growth and Drug Resistance Pathways   syn4939892
# 24  NF1 Dermal Neurofibroma Longitudinal Natural H...   syn8012530
# 25  NF1 Dermal Neurofibroma Longitudinal Natural H...   syn8012530
# 26                           Novel pNF Farming System   syn7217946
# 27  Novel Therapeutics in Malignant Peripheral Ner...  syn11681835
# 28  Novel Treatment Approach to Neurofibromatosis ...   syn4939884
# 29   Exploring the Plexiform Neurofibroma Interactome   syn4939890
# 30   Exploring the Plexiform Neurofibroma Interactome   syn4939890
# 31  Plexiform Neurofibroma Model Systems for Precl...   syn7217928
# 32  Plexiform Neurofibroma Model Systems for Precl...   syn7217928
# 33       pNF Cell Culture for High-Throughput Screens   syn7217935
# 34             pNF Cell Line Characterization Studies   syn4939874
# 35                          pNF Cell Line Development   syn7239479
# 36                 pNF Cell Of Origin using iPS Cells   syn4939918
# 37                                          pNF iPSCs   syn7231973
# 38         Preclinical NF1-MPNST Platform Development  syn11638893
# 39  Prevention and Treatment of Optic Pathway Gliomas   syn4939914
# 40               Regulation of GCPII in Neurofibromas   syn4939904
# 41      Screening of Plexiform Neurofibroma 3D Models   syn4939916
# 42  Search of the molecular mechanisms sustaining ...   syn8016577
# 43  Studying Cells of Origin Using Mouse Models of...  syn11374337
# 44                                  SUZ12 Tumor Study   syn4939908
# 45  Targeting the mechanisms underlying cutaneous ...   syn4939910
# 46  Testing the Pharmacologic role of Molecular Ta...   syn8012599
# 47  The Development and Validation of PRO Measures...   syn4939912
# 48  TRAPping the metabolic adaptations of plexifor...   syn8016650
# 49      Tunable and Reversible NF1 Schwann Cell Model  syn11374349
# 50  Imaging predictors of malignant peripheral ner...  syn17098100
# 51   Pilot Study of Factors Impacting Medication A...  syn17100988
#
#    projectFileviewId projectStatus          dataStatus fundingAgency  \
# 0        syn11601495        Active       Under Embargo          NTAP
# 1        syn13363852        Active       Under Embargo          NTAP
# 2        syn12582871     Completed       Under Embargo          NTAP
# 3        syn15666830        Active       Under Embargo          NTAP
# 4                NaN     Completed                None          NTAP
# 5         syn9922960     Completed       Under Embargo          NTAP
# 6         syn9922960     Completed       Under Embargo          NTAP
# 7         syn8449585     Completed       Under Embargo          NTAP
# 8        syn11601447        Active       Under Embargo          NTAP
# 9        syn11601503        Active       Under Embargo          NTAP
# 10               NaN     Completed                None          NTAP
# 11       syn15666651     Completed           Published          NTAP
# 12       syn15666651     Completed           Published          NTAP
# 13       syn15666651     Completed           Published          NTAP
# 14       syn15666651     Completed           Published          NTAP
# 15        syn7850572     Completed  Partially Released          NTAP
# 16       syn11601488        Active       Under Embargo          NTAP
# 17       syn11601459        Active       Under Embargo          NTAP
# 18       syn15665016        Active       Under Embargo          NTAP
# 19       syn11678415        Active       Under Embargo          NTAP
# 20       syn11601473        Active       Under Embargo          NTAP
# 21       syn11601468        Active       Under Embargo          NTAP
# 22       syn15666926        Active       Under Embargo          NTAP
# 23        syn8449651     Completed                None          NTAP
# 24       syn11678417        Active       Under Embargo          NTAP
# 25       syn11678417        Active       Under Embargo          NTAP
# 26       syn15666932     Completed                None          NTAP
# 27       syn15667121        Active       Under Embargo          NTAP
# 28       syn11678414        Active       Under Embargo          NTAP
# 29        syn8449668     Completed           Published          NTAP
# 30        syn8449668     Completed           Published          NTAP
# 31       syn11581628     Completed           Published          NTAP
# 32       syn11581628     Completed           Published          NTAP
# 33       syn15666931     Completed                None          NTAP
# 34        syn7817226     Completed           Published          NTAP
# 35       syn15666933     Completed           Published          NTAP
# 36       syn15666930        Active       Under Embargo          NTAP
# 37        syn8662666     Completed           Published          NTAP
# 38       syn11678418        Active       Under Embargo          NTAP
# 39       syn15666928        Active       Under Embargo          NTAP
# 40       syn15666677     Completed                None          NTAP
# 41        syn8449638     Completed           Published          NTAP
# 42       syn15666927     Completed       Under Embargo          NTAP
# 43       syn11601451        Active       Under Embargo          NTAP
# 44               NaN     Completed           Published          NTAP
# 45       syn11678416     Completed       Under Embargo          NTAP
# 46       syn15666937        Active       Under Embargo          NTAP
# 47               NaN        Active       Under Embargo          NTAP
# 48       syn15666923        Active       Under Embargo          NTAP
# 49       syn11601481        Active       Under Embargo          NTAP
# 50       syn17100984        Active       Under Embargo          NTAP
# 51       syn17100997        Active       Under Embargo          NTAP
#
#                                               summary  \
# 0   Given the absence of therapeutic options and t...
# 1   Surgery is currently the only treatment option...
# 2   We utilized a genetically engineered mouse mod...
# 3   NF1-related pain is often not well-controlled ...
# 4   Preliminary efficacy studies conducted through...
# 5   To develop and test the feasibility, reliabili...
# 6   To develop and test the feasibility, reliabili...
# 7   Preliminary High-throughput screening (HTS) da...
# 8   There are still gaps in our knowledge of cNF p...
# 9   Our goal is to substantially increase understa...
# 10  The goal of this project is to establish that ...
# 11  Patient Reported Outcome (PRO) measures assess...
# 12  Patient Reported Outcome (PRO) measures assess...
# 13  Patient Reported Outcome (PRO) measures assess...
# 14  Patient Reported Outcome (PRO) measures assess...
# 15  A lack of cellular model systems was identifie...
# 16  Inactivation of the NF1 gene in SCs is believe...
# 17  NF1 cutaneous neurofibromas (cNFs) have some s...
# 18  This project intends to characterize the curre...
# 19  The mechanism of visual acuity loss in optic p...
# 20  Cutaneous or dermal neurofibromas (cNFs) are c...
# 21  Immunity has a central and complex role in tum...
# 22  We aim to identify putative proteomic and/or p...
# 23  Up to 50%> of children with NF1 develop plexif...
# 24  Previous reports have correlated increased bur...
# 25  Previous reports have correlated increased bur...
# 26  Plexiform neurofibromas (PNFs) are relatively ...
# 27  Malignant Peripheral Nerve Sheath Tumor (MPNST...
# 28  Due to the invasive nature and high incidence ...
# 29  NF1 mutations in Schwann cells (SCs) drive neu...
# 30  NF1 mutations in Schwann cells (SCs) drive neu...
# 31  The high vascularity of plexiform neurofibroma...
# 32  The high vascularity of plexiform neurofibroma...
# 33  A cardinal feature of NF1 is the development o...
# 34  A lack of cellular model systems was recently ...
# 35  There is a need for effective therapies for ne...
# 36  In order to identify effective drugs against p...
# 37  Plexiform neurofibromas (pNFs) differ from dis...
# 38  One of the most common malignancies affecting ...
# 39  Optic pathway gliomas (OPGs) develop in 15-20%...
# 40  Preliminary data suggest that GCPII may be use...
# 41  In our primary NTAP project we developed and o...
# 42  Mechanical cues, including tissue geometry and...
# 43  Despite major progress in the understanding of...
# 44  The presentation of NF1 features however is no...
# 45  Cutaneous neurofibromas (CNFs) can be distingu...
# 46  In a recent gene therapy study performed in th...
# 47  Clinical trials for the treatment of PNs in ch...
# 48  We have previously shown that in tumor cells t...
# 49  We will combine the human Schwann cell specifi...
# 50  Malignant peripheral nerve sheath tumors (MPNS...
# 51  Much of the real life impact of NF1 on childre...
#
#                                         summarySource  \
# 0   https://www.synapse.org/#!Synapse:syn11374354/...
# 1   https://www.synapse.org/#!Synapse:syn4939902/w...
# 2   https://www.synapse.org/#!Synapse:syn8016635/w...
# 3   https://www.synapse.org/#!Synapse:syn4939896/w...
# 4   https://www.synapse.org/#!Synapse:syn4939872/w...
# 5   https://www.synapse.org/#!Synapse:syn4939878/w...
# 6   https://www.synapse.org/#!Synapse:syn4939878/w...
# 7   https://www.synapse.org/#!Synapse:syn4939876/w...
# 8   https://www.synapse.org/#!Synapse:syn11374333/...
# 9   https://www.synapse.org/#!Synapse:syn11374357/...
# 10  https://www.synapse.org/#!Synapse:syn4939880/w...
# 11  https://www.synapse.org/#!Synapse:syn4939888/w...
# 12  https://www.synapse.org/#!Synapse:syn4939888/w...
# 13  https://www.synapse.org/#!Synapse:syn4939888/w...
# 14  https://www.synapse.org/#!Synapse:syn4939888/w...
# 15  https://www.synapse.org/#!Synapse:syn4939906/w...
# 16  https://www.synapse.org/#!Synapse:syn11374353/...
# 17  https://www.synapse.org/#!Synapse:syn11374339/...
# 18                                     Robert Allaway
# 19  https://www.synapse.org/#!Synapse:syn4939894/w...
# 20  https://www.synapse.org/#!Synapse:syn11374345/...
# 21  https://www.synapse.org/#!Synapse:syn11374341/...
# 22  https://www.synapse.org/#!Synapse:syn8016599/w...
# 23  https://www.synapse.org/#!Synapse:syn4939892/w...
# 24  https://www.synapse.org/#!Synapse:syn8012530/w...
# 25  https://www.synapse.org/#!Synapse:syn8012530/w...
# 26  https://www.synapse.org/#!Synapse:syn7217946/w...
# 27      https://www.synapse.org/#!Synapse:syn11681835
# 28  https://www.synapse.org/#!Synapse:syn4939884/w...
# 29  https://www.synapse.org/#!Synapse:syn4939890/w...
# 30  https://www.synapse.org/#!Synapse:syn4939890/w...
# 31  https://www.synapse.org/#!Synapse:syn7217928/w...
# 32  https://www.synapse.org/#!Synapse:syn7217928/w...
# 33  https://www.synapse.org/#!Synapse:syn7217935/w...
# 34  https://www.synapse.org/#!Synapse:syn4939874/w...
# 35  https://www.synapse.org/#!Synapse:syn7239479/w...
# 36  https://www.synapse.org/#!Synapse:syn4939918/w...
# 37  https://www.synapse.org/#!Synapse:syn7231973/w...
# 38  https://www.synapse.org/#!Synapse:syn11638893/...
# 39  https://www.synapse.org/#!Synapse:syn4939914/w...
# 40  https://www.synapse.org/#!Synapse:syn4939904/w...
# 41  https://www.synapse.org/#!Synapse:syn4939916/w...
# 42  https://www.synapse.org/#!Synapse:syn8016577/w...
# 43  https://www.synapse.org/#!Synapse:syn11374337/...
# 44  https://www.synapse.org/#!Synapse:syn4939908/w...
# 45  https://www.synapse.org/#!Synapse:syn4939910/w...
# 46  https://www.synapse.org/#!Synapse:syn8012599/w...
# 47  https://www.synapse.org/#!Synapse:syn4939912/w...
# 48  https://www.synapse.org/#!Synapse:syn8016650/w...
# 49  https://www.synapse.org/#!Synapse:syn11374349/...
# 50  https://www.synapse.org/#!Synapse:syn17098100/...
# 51  https://www.synapse.org/#!Synapse:syn17100988/...
#
#                                          projectLeads  \
# 0                                       Alice Soragni
# 1                                  Christine Pratilas
# 2                                               Lu Le
# 3                                        Staci Martin
# 4                                        Nancy Ratner
# 5                                     Nancy Swigonski
# 6                                     Nancy Swigonski
# 7                                          Wade Clapp
# 8                                               Lu Le
# 9                                   Raymond Mattingly
# 10                                    Stephen McKenna
# 11                                       Jin-Shei Lai
# 12                                       Jin-Shei Lai
# 13                                       Jin-Shei Lai
# 14                                       Jin-Shei Lai
# 15                                        Marc Ferrer
# 16                                       Eduard Serra
# 17                                      Peggy Wallace
# 18                                   Jaishri Blakeley
# 19                                     Peter De Blank
# 20                                      David Gutmann
# 21                    Juha Peltonen / Sirkku Peltonen
# 22                                       James Walker
# 23                                       Nancy Ratner
# 24                                      Ashley Cannon
# 25                                      Ashley Cannon
# 26                                     Karlyne Reilly
# 27                                           Ping Chi
# 28                                    Verena Staedtke
# 29                     Jianqiang Wu | Kakajan Komurov
# 30                     Jianqiang Wu | Kakajan Komurov
# 31                                  Raymond Mattingly
# 32                                  Raymond Mattingly
# 33                                        Luis Parada
# 34                     Jaishri Blakeley | Marc Ferrer
# 35                                      Peggy Wallace
# 36                                       Eduard Serra
# 37                                       Eduard Serra
# 38                                       Angela Hirbe
# 39                                   Miriam Bornhorst
# 40  Barbara Slusher | Nancy Ratner | Anat Stemmer-...
# 41                                  Raymond Mattingly
# 42                                    Federica Chiara
# 43                                      Piotr Topilko
# 44                                    Thomas de Raedt
# 45                                Matthew R. Steensma
# 46                                         Wade Clapp
# 47                                     Pamela Wolters
# 48                    Giorgio Colombo | Andrea Rasola
# 49                                        Gabsang Lee
# 50                                             Ina Ly
# 51                                        Shruti Garg
#
#                                          institutions  \
# 0               University of California, Los Angeles
# 1                     Johns Hopkins Medical Institute
# 2     University of Texas Southwestern Medical Center
# 3                       National Institutes of Health
# 4     Cincinnati Children's Hospital Medical Hospital
# 5                                  Indiana University
# 6                                  Indiana University
# 7                                  Indiana University
# 8     University of Texas Southwestern Medical Center
# 9                              Wayne State University
# 10                                                NaN
# 11                            Northwestern University
# 12                            Northwestern University
# 13                            Northwestern University
# 14                            Northwestern University
# 15  National Center for Accelerated Translational ...
# 16                                               IGPT
# 17                              University of Florida
# 18                           Johns Hopkins University
# 19                               University Hospitals
# 20               Washington University of Saint Louis
# 21                                University of Turku
# 22                     Massachusetts General Hospital
# 23      Cincinnati Children's Hospital Medical Center
# 24               University of Alabama Medical Center
# 25               University of Alabama Medical Center
# 26                      National Institutes of Health
# 27             Memorial Sloan Kettering Cancer Center
# 28                    Johns Hopkins Medical Institute
# 29      Cincinnati Children's Hospital Medical Center
# 30      Cincinnati Children's Hospital Medical Center
# 31                             Wayne State University
# 32                             Wayne State University
# 33             Memorial Sloan Kettering Cancer Center
# 34  National Center for Advancing Translational Sc...
# 35                              University of Florida
# 36                                               IGTP
# 37                                               IGTP
# 38               Washington University of Saint Louis
# 39                                Children's National
# 40  Johns Hopkins Medical Institute | Cincinnati C...
# 41                             Wayne State University
# 42                               University of Padova
# 43                                              IBENS
# 44                        Brigham and Womens Hospital
# 45                                    Spectrum Health
# 46                                 Indiana University
# 47                      National Institutes of Health
# 48                                                NaN
# 49                           Johns Hopkins University
# 50                     Massachusetts General Hospital
# 51                          University of Manchester
#
#                                             tumorType         diseaseFocus  \
# 0                              Cutaneous Neurofibroma  Neurofibromatosis 1
# 1   Plexiform Neurofibroma | MPNST | Cutaneous Neu...  Neurofibromatosis 1
# 2                              Plexiform Neurofibroma  Neurofibromatosis 1
# 3                              Plexiform Neurofibroma  Neurofibromatosis 1
# 4                              Plexiform Neurofibroma  Neurofibromatosis 1
# 5                              Plexiform Neurofibroma  Neurofibromatosis 1
# 6                              Plexiform Neurofibroma  Neurofibromatosis 1
# 7                              Plexiform Neurofibroma  Neurofibromatosis 1
# 8                              Cutaneous Neurofibroma  Neurofibromatosis 1
# 9                              Cutaneous Neurofibroma  Neurofibromatosis 1
# 10                             Plexiform Neurofibroma  Neurofibromatosis 1
# 11                             Plexiform Neurofibroma  Neurofibromatosis 1
# 12                             Plexiform Neurofibroma  Neurofibromatosis 1
# 13                             Plexiform Neurofibroma  Neurofibromatosis 1
# 14                             Plexiform Neurofibroma  Neurofibromatosis 1
# 15                             Plexiform Neurofibroma  Neurofibromatosis 1
# 16                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 17                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 18                     Plexiform Neurofibroma | MPNST             Multiple
# 19                                   Low Grade Glioma  Neurofibromatosis 1
# 20                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 21                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 22                             Plexiform Neurofibroma  Neurofibromatosis 1
# 23                             Plexiform Neurofibroma  Neurofibromatosis 1
# 24                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 25                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 26                             Plexiform Neurofibroma  Neurofibromatosis 1
# 27                                              MPNST  Neurofibromatosis 1
# 28                             Plexiform Neurofibroma  Neurofibromatosis 1
# 29                             Plexiform Neurofibroma  Neurofibromatosis 1
# 30                             Plexiform Neurofibroma  Neurofibromatosis 1
# 31                             Plexiform Neurofibroma  Neurofibromatosis 1
# 32                             Plexiform Neurofibroma  Neurofibromatosis 1
# 33                             Plexiform Neurofibroma  Neurofibromatosis 1
# 34                             Plexiform Neurofibroma  Neurofibromatosis 1
# 35                             Plexiform Neurofibroma  Neurofibromatosis 1
# 36                             Plexiform Neurofibroma  Neurofibromatosis 1
# 37                             Plexiform Neurofibroma  Neurofibromatosis 1
# 38                                              MPNST  Neurofibromatosis 1
# 39                                   Low Grade Glioma  Neurofibromatosis 1
# 40                             Plexiform Neurofibroma  Neurofibromatosis 1
# 41                             Plexiform Neurofibroma  Neurofibromatosis 1
# 42                             Plexiform Neurofibroma  Neurofibromatosis 1
# 43                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 44                                              MPNST  Neurofibromatosis 1
# 45                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 46                             Plexiform Neurofibroma  Neurofibromatosis 1
# 47                             Plexiform Neurofibroma  Neurofibromatosis 1
# 48                             Plexiform Neurofibroma  Neurofibromatosis 1
# 49                             Cutaneous Neurofibroma  Neurofibromatosis 1
# 50                                              MPNST  Neurofibromatosis 1
# 51                                                NaN  Neurofibromatosis 1
#
#    featured_x  consortium                                           citation  \
# 0         NaN         NaN                                                NaN
# 1         yes         NaN                                                NaN
# 2         NaN         NaN                                                NaN
# 3         NaN         NaN  Allen, TM et al. The Relationship Between Hear...
# 4         NaN         NaN                                                NaN
# 5         NaN         NaN  Nutakki K et al. Development of the pediatric ...
# 6         NaN         NaN  Draucker CB et al. The health-related quality ...
# 7         NaN         NaN                                                NaN
# 8         NaN         NaN                                                NaN
# 9         NaN         NaN                                                NaN
# 10        NaN         NaN                                                NaN
# 11        NaN         NaN  Lai, JS, et al. Using a qualitative approach t...
# 12        NaN         NaN  Patel ZS, et al.Considerations for conducting ...
# 13        NaN         NaN  Jensen, SE, et al. (in press) Lifespan Develop...
# 14        NaN         NaN  Lai, J-S., et al. (in press). PROMIS and Neuro...
# 15        NaN         NaN  Ferrer M, et al. Pharmacological and genomic p...
# 16        NaN         NaN                                                NaN
# 17        NaN         NaN                                                NaN
# 18        NaN         NaN                                                NaN
# 19        NaN         NaN                                                NaN
# 20        NaN         NaN                                                NaN
# 21        NaN         NaN                                                NaN
# 22        NaN         NaN                                                NaN
# 23        NaN         NaN                                                NaN
# 24        NaN         NaN  Cannon A, et al. Cutaneous neurofibromas in Ne...
# 25        NaN         NaN  Cannon Al, et al. Cutaneous neurofibromas in N...
# 26        NaN         NaN                                                NaN
# 27        NaN         NaN                                                NaN
# 28        NaN         NaN                                                NaN
# 29        NaN         NaN  Choi, K. et al. An inflammatory gene signature...
# 30        NaN         NaN  Fletcher J, et al. Cxcr3-expressing leukocytes...
# 31        NaN         NaN  Brock EJ, Ji K, Reiners JJ Jr. & Mattingly RR....
# 32        NaN         NaN  Kraniak, JM et al.  Development of 3D culture ...
# 33        NaN         NaN                                                NaN
# 34        NaN         NaN  Ferrer M, et al. Pharmacological and genomic p...
# 35        NaN         NaN  Li H., et al. Immortalization of human normal ...
# 36        NaN         NaN                                                NaN
# 37        NaN         NaN                                                NaN
# 38        NaN         NaN                                                NaN
# 39        NaN         NaN                                                NaN
# 40        NaN         NaN                                                NaN
# 41        NaN         NaN  Brock EJ, et al.  How to Target Activated Ras ...
# 42        NaN         NaN                                                NaN
# 43        NaN         NaN                                                NaN
# 44        NaN         NaN                                                NaN
# 45        NaN         NaN                                                NaN
# 46        NaN         NaN                                                NaN
# 47        NaN         NaN                                                NaN
# 48        NaN         NaN                                                NaN
# 49        NaN         NaN                                                NaN
# 50        NaN         NaN                                                NaN
# 51        NaN         NaN                                                NaN
#
#                                   doi featured_y
# 0                                 NaN        NaN
# 1                                 NaN        NaN
# 2                                 NaN        NaN
# 3                  10.1111/papr.12695        NaN
# 4                                 NaN        NaN
# 5           10.1007/s11060-016-2351-2        NaN
# 6                  10.1111/jspn.12174        NaN
# 7                                 NaN        NaN
# 8                                 NaN        NaN
# 9                                 NaN        NaN
# 10                                NaN        NaN
# 11               10.1002/ajmg.a.37987        NaN
# 12          10.1007/s11136-016-1256-z        NaN
# 13                                NaN        NaN
# 14                                NaN        NaN
# 15             10.1038/sdata.2018.106        yes
# 16                                NaN        NaN
# 17                                NaN        NaN
# 18                                NaN        NaN
# 19                                NaN        NaN
# 20                                NaN        NaN
# 21                                NaN        NaN
# 22                                NaN        NaN
# 23                                NaN        NaN
# 24          10.1186/s13023-018-0772-z        NaN
# 25          10.1186/s13023-018-0772-z        NaN
# 26                                NaN        NaN
# 27                                NaN        NaN
# 28                                NaN        NaN
# 29                  10.1038/srep43315        NaN
# 30          10.1172/jci.insight.98601        NaN
# 31  10.2174/1389557515666151001154002        NaN
# 32    10.1016/j.expneurol.2017.10.012        NaN
# 33                                NaN        NaN
# 34             10.1038/sdata.2018.106        NaN
# 35          10.1038/labinvest.2016.88        NaN
# 36                                NaN        NaN
# 37                                NaN        NaN
# 38                                NaN        NaN
# 39                                NaN        NaN
# 40                                NaN        NaN
# 41  10.2174/1389557515666151001154002        NaN
# 42                                NaN        NaN
# 43                                NaN        NaN
# 44                                NaN        NaN
# 45                                NaN        NaN
# 46                                NaN        NaN
# 47                                NaN        NaN
# 48                                NaN        NaN
# 49                                NaN        NaN
# 50                                NaN        NaN
# 51                                NaN        NaN

# %%
project_info_df = project_info_df[
    [ 'projectName',
     'projectId',
     'projectFileviewId',
     'dataStatus',
     'fundingAgency',
     'projectLeads',
     'institutions',
     'tumorType',
     'diseaseFocus',
     'citation', 
     'doi']
]

# %%
publication_count = list(project_info_df.groupby(['projectId']))
dfs[1]['publication_count'] = [len(x[1]) if len(x[1]) != 1 else 0 for x in publication_count]

# %%
dfs[0] = dfs[0].astype(object).replace(numpy.nan, '')

# %%
dfs[1]['publication_geodata_produced'] = 0  ### don't have data location...run getPMIDDF or set to zero

# %%
# File attributes
# remove tools files (subset of all datafiles) from all datafiles
tools_files_id = list(set(dfs[2]["id"].unique()).intersection(set(dfs[3]["study"].unique())))

# no files that are also tools for NTAP
list(set(dfs[3]["study"].unique()).intersection( set(dfs[2]["id"].unique())))
# Out:
# []

# %%
dfs[2].rename(index=str, columns={"id": "fileId", "name": "name_file", "createdOn": "createdOn_file",
                                  "modifiedOn": "modifiedOn_file", "modifiedBy": "modifiedBy_file"}, inplace=True)
dfs[3].rename(index=str, columns={"id": "fileId", "name": "name_file", "createdOn": "createdOn_file",
                                  "modifiedOn": "modifiedOn_file", "modifiedBy": "modifiedBy_file", "study" :"projectId"}, inplace=True)

# %%
cols_to_add2 = dfs[3].columns.difference(dfs[2].columns)
cols_to_add3 = dfs[2].columns.difference(dfs[3].columns)
dfs[2] = pandas.concat([dfs[2], pandas.DataFrame(columns=cols_to_add2)])
dfs[3] = pandas.concat([dfs[3], pandas.DataFrame(columns=cols_to_add3)])
# Out:
# [WARNING] /Users/xdoan/anaconda2/envs/py3.5/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#
# [WARNING] /Users/xdoan/anaconda2/envs/py3.5/lib/python3.5/site-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
# concat files and tools to get all the files information data frame
file_info_df = pandas.concat([dfs[3], dfs[2]], sort = False)

# %%
# file_info_df[[cols for cols in list(file_info_df.columns) if cols in csbc_atr]].columns

# %%
final_df = pandas.merge( dfs[1], file_info_df, on= ['projectId'], how='left')

# %%
# (dfs[1]["consortium"]).describe()

# %%
final_df = final_df.drop(
    ["summary_x",
     "summarySource",
     "featured_x",
     "consortium_x",
     "fundingAgency_y",
     "featured_y",
     "tumorType_y",
     "etag"]
    , axis = 1)

# %%
final_df.columns
# Out:
# Index(['projectName', 'projectId', 'projectFileviewId', 'projectStatus',
#        'dataStatus', 'fundingAgency_x', 'projectLeads', 'institutions',
#        'tumorType_x', 'diseaseFocus', 'publication_count',
#        'publication_geodata_produced', 'age', 'assay', 'benefactorId',
#        'consortium_y', 'contact', 'createdOn_file', 'dataSubtype', 'dataType',
#        'diagnosis', 'disease', 'fileFormat', 'fileId', 'individualID',
#        'isCellLine', 'isMultiIndividual', 'isMultiSpecimen', 'link',
#        'modifiedOn_file', 'name_file', 'nf1Genotype', 'nf2Genotype',
#        'parentId', 'readPair', 'reportMilestone', 'resourceType', 'sex',
#        'softwareLink', 'softwareName', 'species', 'specimenID', 'studyId',
#        'studyName', 'subtype', 'summary_y', 'type'],
#       dtype='object')

# %%
final_df.rename(columns={
    "fundingAgency_x":"fundingAgency",
    "tumorType_x":"tumorType", 
    "projectName":'name_project',
    "isCellLine":"cellLine",
    "consortium_y" : "consortium"},
                inplace=True)

# %%
# annotate tools files to be a resourceType tool - for now
final_df.loc[final_df.summary_y.isin(list(dfs[3].summary)), 'resourceType'] = 'tool'

# %%
pandas.set_option('display.max_columns', 500)
final_df.describe(include="all")
# Out:
#                                             name_project   projectId  \
# count                                               4623        4623
# unique                                                45          45
# top     A Nerve Sheath Tumor Bank from Patients with NF1  syn4939902
# freq                                                1898        1898
# mean                                                 NaN         NaN
# std                                                  NaN         NaN
# min                                                  NaN         NaN
# 25%                                                  NaN         NaN
# 50%                                                  NaN         NaN
# 75%                                                  NaN         NaN
# max                                                  NaN         NaN
#
#        projectFileviewId projectStatus     dataStatus fundingAgency  \
# count               4619          4623           4623          4623
# unique                41             2              4             1
# top          syn13363852        Active  Under Embargo          NTAP
# freq                1898          3743           3914          4623
# mean                 NaN           NaN            NaN           NaN
# std                  NaN           NaN            NaN           NaN
# min                  NaN           NaN            NaN           NaN
# 25%                  NaN           NaN            NaN           NaN
# 50%                  NaN           NaN            NaN           NaN
# 75%                  NaN           NaN            NaN           NaN
# max                  NaN           NaN            NaN           NaN
#
#               projectLeads                     institutions  \
# count                 4623                             4621
# unique                  37                               28
# top     Christine Pratilas  Johns Hopkins Medical Institute
# freq                  1898                             1899
# mean                   NaN                              NaN
# std                    NaN                              NaN
# min                    NaN                              NaN
# 25%                    NaN                              NaN
# 50%                    NaN                              NaN
# 75%                    NaN                              NaN
# max                    NaN                              NaN
#
#                                                 tumorType  \
# count                                                4622
# unique                                                  6
# top     Plexiform Neurofibroma | MPNST | Cutaneous Neu...
# freq                                                 1898
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                diseaseFocus  publication_count  publication_geodata_produced  \
# count                  4623        4623.000000                        4623.0
# unique                    2                NaN                           NaN
# top     Neurofibromatosis 1                NaN                           NaN
# freq                   4530                NaN                           NaN
# mean                    NaN           0.289855                           0.0
# std                     NaN           0.705360                           0.0
# min                     NaN           0.000000                           0.0
# 25%                     NaN           0.000000                           0.0
# 50%                     NaN           0.000000                           0.0
# 75%                     NaN           0.000000                           0.0
# max                     NaN           4.000000                           0.0
#
#         age     assay benefactorId consortium       contact createdOn_file  \
# count   120      4105         4600       4590             3           4623
# unique   26        16           43          6             3           4601
# top      41  exomeSeq  syn17866464       Open  Eduard Serra
# freq     12      1810         1805       1970             1             23
# mean    NaN       NaN          NaN        NaN           NaN            NaN
# std     NaN       NaN          NaN        NaN           NaN            NaN
# min     NaN       NaN          NaN        NaN           NaN            NaN
# 25%     NaN       NaN          NaN        NaN           NaN            NaN
# 50%     NaN       NaN          NaN        NaN           NaN            NaN
# 75%     NaN       NaN          NaN        NaN           NaN            NaN
# max     NaN       NaN          NaN        NaN           NaN            NaN
#
#        dataSubtype         dataType            diagnosis disease fileFormat  \
# count         3996             4133                 4093       3       4395
# unique           4                9                    1       1         32
# top            raw  genomicVariants  Neurofibromatosis 1     NF1        csv
# freq          2139             2087                 4093       3       1324
# mean           NaN              NaN                  NaN     NaN        NaN
# std            NaN              NaN                  NaN     NaN        NaN
# min            NaN              NaN                  NaN     NaN        NaN
# 25%            NaN              NaN                  NaN     NaN        NaN
# 50%            NaN              NaN                  NaN     NaN        NaN
# 75%            NaN              NaN                  NaN     NaN        NaN
# max            NaN              NaN                  NaN     NaN        NaN
#
#              fileId individualID cellLine isMultiIndividual isMultiSpecimen  \
# count          4600         3714     2710              2703            2657
# unique         4600          199        2                 2               2
# top     syn18133885        BI386    False             False           False
# freq              1          149     1951              2636            2547
# mean            NaN          NaN      NaN               NaN             NaN
# std             NaN          NaN      NaN               NaN             NaN
# min             NaN          NaN      NaN               NaN             NaN
# 25%             NaN          NaN      NaN               NaN             NaN
# 50%             NaN          NaN      NaN               NaN             NaN
# 75%             NaN          NaN      NaN               NaN             NaN
# max             NaN          NaN      NaN               NaN             NaN
#
#                                                      link modifiedOn_file  \
# count                                                   3            4623
# unique                                                  3            4601
# top     https://www.hopkinsmedicine.org/kimmel_cancer_...
# freq                                                    1              23
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#         name_file nf1Genotype nf2Genotype     parentId readPair  \
# count        4600        2738        1619         4600     4623
# unique       4577           4           1          183        1
# top     .DS_Store         -/-         +/+  syn11492076
# freq            3        2446        1619          600     4623
# mean          NaN         NaN         NaN          NaN      NaN
# std           NaN         NaN         NaN          NaN      NaN
# min           NaN         NaN         NaN          NaN      NaN
# 25%           NaN         NaN         NaN          NaN      NaN
# 50%           NaN         NaN         NaN          NaN      NaN
# 75%           NaN         NaN         NaN          NaN      NaN
# max           NaN         NaN         NaN          NaN      NaN
#
#         reportMilestone      resourceType   sex  \
# count        671.000000              4594  2535
# unique              NaN                 6     4
# top                 NaN  experimentalData  male
# freq                NaN              4272  1295
# mean          11.400894               NaN   NaN
# std            1.800149               NaN   NaN
# min            6.000000               NaN   NaN
# 25%           12.000000               NaN   NaN
# 50%           12.000000               NaN   NaN
# 75%           12.000000               NaN   NaN
# max           12.000000               NaN   NaN
#
#                                              softwareLink  \
# count                                                   3
# unique                                                  3
# top     https://www.hopkinsmedicine.org/kimmel_cancer_...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                         softwareName species specimenID  \
# count                                              3    4078       3719
# unique                                             3       4        871
# top     The Johns Hopkins NF1 Biospecimen Repository   Human  BI386-014
# freq                                               1    3945         49
# mean                                             NaN     NaN        NaN
# std                                              NaN     NaN        NaN
# min                                              NaN     NaN        NaN
# 25%                                              NaN     NaN        NaN
# 50%                                              NaN     NaN        NaN
# 75%                                              NaN     NaN        NaN
# max                                              NaN     NaN        NaN
#
#            studyId                                         studyName  \
# count         4213                                              4192
# unique          32                                                21
# top     syn4939902  A Nerve Sheath Tumor Bank from Patients with NF1
# freq          1853                                              1842
# mean           NaN                                               NaN
# std            NaN                                               NaN
# min            NaN                                               NaN
# 25%            NaN                                               NaN
# 50%            NaN                                               NaN
# 75%            NaN                                               NaN
# max            NaN                                               NaN
#
#               subtype                                          summary_y  \
# count               3                                                  3
# unique              3                                                  3
# top     visualization  A set of immortalized pluripotent stem cells (...
# freq                1                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#                  type
# count               3
# unique              2
# top     bench science
# freq                2
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
# # double check if we didn't loose a project
if len(final_df.projectId.unique()) == len(dfs[1].projectId):
    print("All projects were successfully associated with files")
else:
    print("lost a project")
# Out:
# All projects were successfully associated with files

# %%
# check types
col_types = [col for col in list( final_df.columns ) if final_df[col].dtype == numpy.float64]
print("column names of type numpy.float64 \n:", col_types)
# Out:
# column names of type numpy.float64
# : ['createdOn_file', 'modifiedOn_file', 'readPair', 'reportMilestone']

# %%
len(final_df.columns)
# Out:
# 47

# %%
def changeFloatToInt(final_df, col):
    """

    :param final_df:
    :param col:
    :return:
    """
    final_df[col] = final_df[col].fillna(0).astype(int)
    final_df[col].replace(0, '', inplace=True)

# %%
cols = ['createdOn_file','modifiedOn_file','readPair']

[changeFloatToInt(final_df, col) for col in cols]
# Out:
# [None, None, None]

# %%
### parent is NTAP now
table = synapseclient.table.build_table("NTAP Project Information Integration", 'syn4939478', final_df)

# %%
syn = synapseclient.Synapse()
syn.login()
# Out:
# Welcome, xengie.doan!

# %%
table = syn.store(table)
